# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
pwd
# Out:
# '/Users/vickiwei/Desktop/Capstone_1'

# %%
df_covid = pd.read_csv ('/Users/vickiwei/Desktop/Capstone_1/data/covid_confirmed.csv')

# %%
df_covid
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 262            NaN  West Bank and Gaza  31.952200  35.233200        0
# 263            NaN      Western Sahara  24.215500 -12.885800        0
# 264            NaN               Yemen  15.552727  48.516388        0
# 265            NaN              Zambia -13.133897  27.849332        0
# 266            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  10/16/20  10/17/20  \
# ...

# %%
df_covid = df_covid.sort_values(by=['10/19/20'],ascending=False)

# %%
df_covid.iloc[243,:]
# Out:
# Province/State        NaN
# Country/Region         US
# Lat                    40
# Long                 -100
# 1/22/20                 1
#                    ...
# 10/21/20          8336031
# 10/22/20          8407702
# 10/23/20          8491459
# 10/24/20          8575177
# 10/25/20          8635966
# Name: 243, Length: 282, dtype: object

# %%
df_covid
# Out:
#             Province/State   Country/Region        Lat        Long  1/22/20  \
# 243                    NaN               US  40.000000 -100.000000        1
# 143                    NaN            India  20.593684   78.962880        0
# 30                     NaN           Brazil -14.235000  -51.925300        0
# 208                    NaN           Russia  61.524010  105.318756        0
# 6                      NaN        Argentina -38.416100  -63.616700        0
# ..                     ...              ...        ...         ...      ...
# 46   Northwest Territories           Canada  64.825500 -124.845700        0
# 247               Anguilla   United Kingdom  18.220600  -63.068600        0
# 223                    NaN  Solomon Islands  -9.645700  160.156200        0
# 85                   Tibet            China  31.692700   88.092400        0
# 41        Diamond Princess           Canada   0.000000    0.000000        0
#
# ...

# %%
df_top_10 = df_covid.iloc[:9,:]

# %%
df_top_10.plot.line()
# Out:
# <AxesSubplot:>
